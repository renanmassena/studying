# %%
import pandas as pd

# %% [markdown]
# ### Series

# %%
carros = ['Gol', 'Ferrari', 'BMW']
carros
# Out:
# ['Gol', 'Ferrari', 'BMW']

# %%
pd.Series(carros)
# Out:
# 0        Gol
# 1    Ferrari
# 2        BMW
# dtype: object

# %%
teste = pd.Series(carros)

# %%
type(teste)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### DataFrames

# %%
dados = [
         {'Nome': 'Gol', 'Motor': 1.0, 'Ano': 1999, 'Km':100000},
         {'Nome': 'Ferrari', 'Motor': 5.0, 'Ano': 2020, 'Km':900},
         {'Nome': 'BMW', 'Motor': 2.0, 'Ano': 2021, 'Km':18000},
]

# %%
dados
# Out:
# [{'Ano': 1999, 'Km': 100000, 'Motor': 1.0, 'Nome': 'Gol'},
#  {'Ano': 2020, 'Km': 900, 'Motor': 5.0, 'Nome': 'Ferrari'},
#  {'Ano': 2021, 'Km': 18000, 'Motor': 2.0, 'Nome': 'BMW'}]

# %%
dados[0]
# Out:
# {'Ano': 1999, 'Km': 100000, 'Motor': 1.0, 'Nome': 'Gol'}

# %%
print(dados[2]['Nome'])
print(dados[2]['Ano'])
# Out:
# BMW
# 2021

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      BMW    2.0  2021   18000

# %%
dataset['Motor']
# Out:
# 0    1.0
# 1    5.0
# 2    2.0
# Name: Motor, dtype: float64

# %%
dataset[['Nome', 'Motor']]
# Out:
#       Nome  Motor
# 0      Gol    1.0
# 1  Ferrari    5.0
# 2      BMW    2.0

# %%
dataset[['Nome']]
# Out:
#       Nome
# 0      Gol
# 1  Ferrari
# 2      BMW

# %%
dados = {
    'Nome': ['Gol', 'Ferrari', 'Bmw'],
    'Motor': [1.0, 5.0, 2.0],
    'Ano': [1999, 2020, 2021],
    'Km': [100000, 900, 18000]
}

# %%
dados
# Out:
# {'Ano': [1999, 2020, 2021],
#  'Km': [100000, 900, 18000],
#  'Motor': [1.0, 5.0, 2.0],
#  'Nome': ['Gol', 'Ferrari', 'Bmw']}

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000

# %% [markdown]
# ### Carregando arquivos externos

# %%
# Para montar o drive e carregar o dataset
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/colab/aluguel.csv'
# Out:
# Mounted at /content/drive

# %%
aluguel = pd.read_csv(path, sep=';')

# %%
aluguel
# Out:
#                           Tipo                Bairro  ...  Condominio    IPTU
# 0                    Quitinete            Copacabana  ...       500.0    60.0
# 1                         Casa       Jardim Botânico  ...         NaN     NaN
# 2      Conjunto Comercial/Sala       Barra da Tijuca  ...      4020.0  1111.0
# 3                  Apartamento                Centro  ...       390.0    20.0
# 4                  Apartamento          Higienópolis  ...       230.0     NaN
# ...                        ...                   ...  ...         ...     ...
# 32955                Quitinete                Centro  ...       350.0    25.0
# 32956              Apartamento           Jacarepaguá  ...       800.0    40.0
# 32957              Apartamento  São Francisco Xavier  ...       509.0    37.0
# 32958              Apartamento                Leblon  ...       760.0     NaN
# 32959  Conjunto Comercial/Sala                Centro  ...      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
aluguel.head()
# Out:
#                       Tipo           Bairro  ...  Condominio    IPTU
# 0                Quitinete       Copacabana  ...       500.0    60.0
# 1                     Casa  Jardim Botânico  ...         NaN     NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...      4020.0  1111.0
# 3              Apartamento           Centro  ...       390.0    20.0
# 4              Apartamento     Higienópolis  ...       230.0     NaN
#
# [5 rows x 9 columns]

# %%
aluguel.tail()
# Out:
#                           Tipo                Bairro  ...  Condominio    IPTU
# 32955                Quitinete                Centro  ...       350.0    25.0
# 32956              Apartamento           Jacarepaguá  ...       800.0    40.0
# 32957              Apartamento  São Francisco Xavier  ...       509.0    37.0
# 32958              Apartamento                Leblon  ...       760.0     NaN
# 32959  Conjunto Comercial/Sala                Centro  ...      4206.0  1109.0
#
# [5 rows x 9 columns]

# %%
aluguel.shape
# Out:
# (32960, 9)

# %%
aluguel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
aluguel.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
aluguel['Quartos']
# Out:
# 0        1
# 1        2
# 2        0
# 3        1
# 4        1
#         ..
# 32955    0
# 32956    3
# 32957    2
# 32958    2
# 32959    0
# Name: Quartos, Length: 32960, dtype: int64

# %%
aluguel[['Bairros', 'Quartos']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-9ae27b8e1998> in <module>()
# ----> 1 aluguel[['Bairros', 'Quartos']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
aluguel[['Bairro', 'Quartos']]
# Out:
#                      Bairro  Quartos
# 0                Copacabana        1
# 1           Jardim Botânico        2
# 2           Barra da Tijuca        0
# 3                    Centro        1
# 4              Higienópolis        1
# ...                     ...      ...
# 32955                Centro        0
# 32956           Jacarepaguá        3
# 32957  São Francisco Xavier        2
# 32958                Leblon        2
# 32959                Centro        0
#
# [32960 rows x 2 columns]

# %%
aluguel['País'] = 'Brasil'

# %%
aluguel
# Out:
#                           Tipo                Bairro  ...    IPTU    País
# 0                    Quitinete            Copacabana  ...    60.0  Brasil
# 1                         Casa       Jardim Botânico  ...     NaN  Brasil
# 2      Conjunto Comercial/Sala       Barra da Tijuca  ...  1111.0  Brasil
# 3                  Apartamento                Centro  ...    20.0  Brasil
# 4                  Apartamento          Higienópolis  ...     NaN  Brasil
# ...                        ...                   ...  ...     ...     ...
# 32955                Quitinete                Centro  ...    25.0  Brasil
# 32956              Apartamento           Jacarepaguá  ...    40.0  Brasil
# 32957              Apartamento  São Francisco Xavier  ...    37.0  Brasil
# 32958              Apartamento                Leblon  ...     NaN  Brasil
# 32959  Conjunto Comercial/Sala                Centro  ...  1109.0  Brasil
#
# [32960 rows x 10 columns]

# %%
aluguel['Valor_Completo'] = aluguel['Valor'] + aluguel['Condominio']

# %%
aluguel
# Out:
#                           Tipo                Bairro  ...    País  Valor_Completo
# 0                    Quitinete            Copacabana  ...  Brasil          2200.0
# 1                         Casa       Jardim Botânico  ...  Brasil             NaN
# 2      Conjunto Comercial/Sala       Barra da Tijuca  ...  Brasil          9220.0
# 3                  Apartamento                Centro  ...  Brasil          1190.0
# 4                  Apartamento          Higienópolis  ...  Brasil          1030.0
# ...                        ...                   ...  ...     ...             ...
# 32955                Quitinete                Centro  ...  Brasil          1150.0
# 32956              Apartamento           Jacarepaguá  ...  Brasil          2600.0
# 32957              Apartamento  São Francisco Xavier  ...  Brasil          1909.0
# 32958              Apartamento                Leblon  ...  Brasil          3760.0
# ...

# %% [markdown]
# ### Filtros

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000

# %%
dataset.append({'Nome': 'Jetta', 'Motor': 2.0, 'Ano': 2015, 'Km':150000}, ignore_index=True)
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000
# 3    Jetta    2.0  2015  150000

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000

# %%
dataset = dataset.append({'Nome': 'Jetta', 'Motor': 2.0, 'Ano': 2015, 'Km':150000}, ignore_index=True)

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000
# 3    Jetta    2.0  2015  150000

# %%
dataset[:3]
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000

# %%
dataset[:3]['Nome']
# Out:
# 0        Gol
# 1    Ferrari
# 2        Bmw
# Name: Nome, dtype: object

# %%
dataset[:3][['Nome', 'Motor']]
# Out:
#       Nome  Motor
# 0      Gol    1.0
# 1  Ferrari    5.0
# 2      Bmw    2.0

# %%
dataset[:3, :1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-609c7b8af01f> in <module>()
# ----> 1 dataset[:3, :1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000
# 3    Jetta    2.0  2015  150000

# %%
dataset.iloc[:3, 1]
# Out:
# 0    1.0
# 1    5.0
# 2    2.0
# Name: Motor, dtype: float64

# %%
dataset.iloc[0, 1]
# Out:
# 1.0

# %%
dataset.iloc[2:4, :]
# Out:
#     Nome  Motor   Ano      Km
# 2    Bmw    2.0  2021   18000
# 3  Jetta    2.0  2015  150000

# %%
dataset.iloc[2:4, -1]
# Out:
# 2     18000
# 3    150000
# Name: Km, dtype: int64

# %%
dataset.iloc[:, 0:2]
# Out:
#       Nome  Motor
# 0      Gol    1.0
# 1  Ferrari    5.0
# 2      Bmw    2.0
# 3    Jetta    2.0

# %%
dataset.iloc[:, [0, 2, 3]]
# Out:
#       Nome   Ano      Km
# 0      Gol  1999  100000
# 1  Ferrari  2020     900
# 2      Bmw  2021   18000
# 3    Jetta  2015  150000

# %%
dataset.iloc[:, [3, 0, 2]]
# Out:
#        Km     Nome   Ano
# 0  100000      Gol  1999
# 1     900  Ferrari  2020
# 2   18000      Bmw  2021
# 3  150000    Jetta  2015

# %%
dataset.iloc[:, [3, 3, 3]]
# Out:
#        Km      Km      Km
# 0  100000  100000  100000
# 1     900     900     900
# 2   18000   18000   18000
# 3  150000  150000  150000

# %%
df_km = dataset.iloc[:, [3, 3, 3]]

# %%
df_km
# Out:
#        Km      Km      Km
# 0  100000  100000  100000
# 1     900     900     900
# 2   18000   18000   18000
# 3  150000  150000  150000

# %%
dataset
# Out:
#       Nome  Motor   Ano      Km
# 0      Gol    1.0  1999  100000
# 1  Ferrari    5.0  2020     900
# 2      Bmw    2.0  2021   18000
# 3    Jetta    2.0  2015  150000

# %%
dataset = dataset.iloc[:, [0, 2, 1, 3]]

# %%
dataset
# Out:
#       Nome   Ano  Motor      Km
# 0      Gol  1999    1.0  100000
# 1  Ferrari  2020    5.0     900
# 2      Bmw  2021    2.0   18000
# 3    Jetta  2015    2.0  150000

# %%
dataset.columns
# Out:
# Index(['Nome', 'Ano', 'Motor', 'Km'], dtype='object')

# %%
dataset = dataset[['Nome', 'Ano',  'Km', 'Motor']]

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset.iloc[:, [3, 3, 3]]
# Out:
#    Motor  Motor  Motor
# 0    1.0    1.0    1.0
# 1    5.0    5.0    5.0
# 2    2.0    2.0    2.0
# 3    2.0    2.0    2.0

# %%
dataset = dataset.set_index('Nome')

# %%
dataset
# Out:
#           Ano      Km  Motor
# Nome
# Gol      1999  100000    1.0
# Ferrari  2020     900    5.0
# Bmw      2021   18000    2.0
# Jetta    2015  150000    2.0

# %%
dataset = dataset.reset_index()

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset.set_index('Nome', inplace=True)

# %%
dataset
# Out:
#           Ano      Km  Motor
# Nome
# Gol      1999  100000    1.0
# Ferrari  2020     900    5.0
# Bmw      2021   18000    2.0
# Jetta    2015  150000    2.0

# %%
dataset.iloc[0, [1, 2]]
# Out:
# Km       100000.0
# Motor         1.0
# Name: Gol, dtype: float64

# %%
dataset.loc[['Gol', 'Bmw']]
# Out:
#        Ano      Km  Motor
# Nome
# Gol   1999  100000    1.0
# Bmw   2021   18000    2.0

# %%
dataset.loc[['Gol', 'Bmw'], ['Km']]
# Out:
#           Km
# Nome
# Gol   100000
# Bmw    18000

# %%
dataset.reset_index(inplace=True)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset.loc[[0]]
# Out:
#   Nome   Ano      Km  Motor
# 0  Gol  1999  100000    1.0

# %%
dataset['Ano'] < 2021
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# Name: Ano, dtype: bool

# %%
df_teste = dataset[dataset['Ano'] < 2021]

# %%
df_teste
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 3    Jetta  2015  150000    2.0

# %%
df_teste.iloc[2]
# Out:
# Nome      Jetta
# Ano        2015
# Km       150000
# Motor       2.0
# Name: 3, dtype: object

# %%
df_teste.loc[3]
# Out:
# Nome      Jetta
# Ano        2015
# Km       150000
# Motor       2.0
# Name: 3, dtype: object

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset['Ano'].iloc[0] = 2000
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  2000  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  2000  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset['Ano'] > 2000
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Ano, dtype: bool

# %%
dataset[dataset['Ano'] > 2000]
# Out:
#       Nome   Ano      Km  Motor
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
maiores_que_2000 = dataset['Ano'] > 2000

# %%
maiores_que_2000
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Ano, dtype: bool

# %%
dataset[maiores_que_2000]
# Out:
#       Nome   Ano      Km  Motor
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset[(maiores_que_2000) & (dataset['Km'] < 150000)]
# Out:
#       Nome   Ano     Km  Motor
# 1  Ferrari  2020    900    5.0
# 2      Bmw  2021  18000    2.0

# %%
dataset[(maiores_que_2000) | (dataset['Km'] < 150000)]
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  2000  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset.query('Ano > 2000 or Km < 150000')
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  2000  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset.query('Ano > 2000 and Km < 150000')
# Out:
#       Nome   Ano     Km  Motor
# 1  Ferrari  2020    900    5.0
# 2      Bmw  2021  18000    2.0

# %%
dataset.head()
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
aluguel.head()
# Out:
#                       Tipo           Bairro  ...    País  Valor_Completo
# 0                Quitinete       Copacabana  ...  Brasil          2200.0
# 1                     Casa  Jardim Botânico  ...  Brasil             NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...  Brasil          9220.0
# 3              Apartamento           Centro  ...  Brasil          1190.0
# 4              Apartamento     Higienópolis  ...  Brasil          1030.0
#
# [5 rows x 11 columns]

# %%
aluguel.shape
# Out:
# (32960, 11)

# %%
dataset.sort_values(by='Ano', ascending=False)
# Out:
#       Nome   Ano      Km  Motor
# 2      Bmw  2021   18000    2.0
# 1  Ferrari  2020     900    5.0
# 3    Jetta  2015  150000    2.0
# 0      Gol  1999  100000    1.0

# %%
dataset.to_excel('carros_novos.xlsx')

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor
# 0      Gol  1999  100000    1.0
# 1  Ferrari  2020     900    5.0
# 2      Bmw  2021   18000    2.0
# 3    Jetta  2015  150000    2.0

# %%
dataset['Novo'] = 0

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo
# 0      Gol  1999  100000    1.0     0
# 1  Ferrari  2020     900    5.0     0
# 2      Bmw  2021   18000    2.0     0
# 3    Jetta  2015  150000    2.0     0

# %%
dataset[dataset['Ano'] >= 2020]
# Out:
#       Nome   Ano     Km  Motor  Novo
# 1  Ferrari  2020    900    5.0     0
# 2      Bmw  2021  18000    2.0     0

# %%
dataset['Novo'][dataset['Ano'] >= 2020] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo
# 0      Gol  1999  100000    1.0     0
# 1  Ferrari  2020     900    5.0     1
# 2      Bmw  2021   18000    2.0     1
# 3    Jetta  2015  150000    2.0     0

# %%
dataset = dataset.append({'Nome': 'Audi',
                'Ano': 2017,
                'Km': 70000,
                'Motor': 2.0,
                'Novo':0
                }, ignore_index=True)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo
# 0      Gol  1999  100000    1.0     0
# 1  Ferrari  2020     900    5.0     1
# 2      Bmw  2021   18000    2.0     1
# 3    Jetta  2015  150000    2.0     0
# 4     Audi  2017   70000    2.0     0

# %%
dataset['Novo'].value_counts()
# Out:
# 0    3
# 1    2
# Name: Novo, dtype: int64

# %%
aluguel[aluguel['Bairro'] == 'Flamengo'].count()
# Out:
# Tipo              812
# Bairro            812
# Quartos           812
# Vagas             812
# Suites            812
# Area              812
# Valor             812
# Condominio        790
# IPTU              626
# País              812
# Valor_Completo    790
# dtype: int64

# %%
aluguel['Bairro'].value_counts()
# Out:
# Barra da Tijuca             6259
# Centro                      3258
# Copacabana                  3186
# Ipanema                     2233
# Recreio dos Bandeirantes    2127
#                             ...
# Cachamorra                     1
# Vasco da Gama                  1
# Cidade de Deus                 1
# Itaguaí                        1
# Sepetiba                       1
# Name: Bairro, Length: 162, dtype: int64

# %%
dataset['Novo'].value_counts()
# Out:
# 0    3
# 1    2
# Name: Novo, dtype: int64

# %%
dataset.groupby(['Motor'])['Km'].agg(['count', 'max', 'min', 'mean', 'median'])
# Out:
#        count     max     min           mean    median
# Motor
# 1.0        1  100000  100000  100000.000000  100000.0
# 2.0        3  150000   18000   79333.333333   70000.0
# 5.0        1     900     900     900.000000     900.0

# %%
aluguel['Quartos'].value_counts()
# Out:
# 0      9851
# 2      8419
# 3      6829
# 1      4000
# 4      3065
# 5       572
# 6       137
# 7        30
# 8        19
# 10       11
# 27        7
# 11        4
# 12        4
# 9         4
# 100       2
# 14        2
# 23        1
# 32        1
# 24        1
# 22        1
# Name: Quartos, dtype: int64

# %%
aluguel.groupby(['Bairro']).median().sort_values(by='IPTU', ascending=False)
# Out:
#                      Quartos  Vagas  ...     IPTU  Valor_Completo
# Bairro                               ...
# Jardim América           1.0    0.0  ...  11133.5          1100.0
# Cidade de Deus           0.0   90.0  ...   6000.0             NaN
# Pavuna                   0.0    0.0  ...   3400.0         47567.0
# Caju                     0.0    0.0  ...   2678.0        133790.0
# Parada de Lucas          0.0    0.0  ...   2527.0          1152.0
# ...                      ...    ...  ...      ...             ...
# Senador Vasconcelos      1.0    1.0  ...      NaN          1030.0
# Sepetiba                 0.0    2.0  ...      NaN             NaN
# Turiaçu                  2.0    0.0  ...      NaN           736.0
# Vasco da Gama            0.0   20.0  ...      NaN             NaN
# Vila Kosmos              2.0    0.5  ...      NaN          1396.0
#
# [162 rows x 8 columns]

# %%
aluguel.groupby(['Bairro']).median().sort_values(by='Condominio', ascending=False)
# Out:
#                         Quartos  Vagas  ...    IPTU  Valor_Completo
# Bairro                                  ...
# Caju                        0.0    0.0  ...  2678.0        133790.0
# Cidade Nova                 0.0    4.0  ...  1195.0         84474.5
# Pavuna                      0.0    0.0  ...  3400.0         47567.0
# Arpoador                    2.0    1.5  ...   518.0         10900.0
# São Conrado                 3.0    2.0  ...   500.0          7730.0
# ...                         ...    ...  ...     ...             ...
# Ricardo de Albuquerque      1.0    0.0  ...     NaN             NaN
# Senador Camará              1.0    0.5  ...     NaN             NaN
# Sepetiba                    0.0    2.0  ...     NaN             NaN
# Vasco da Gama               0.0   20.0  ...     NaN             NaN
# Vila Militar                0.5    0.0  ...   291.0             NaN
#
# [162 rows x 8 columns]

# %% [markdown]
# ## O que está acontecendo aqui?
# - Pq bairros como Copacabana e Barra não aparecem entre os mais caros?
# - Existem quantos valores ausentes nesses bairros?
# - Este é o problema?

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo
# 0      Gol  1999  100000    1.0     0
# 1  Ferrari  2020     900    5.0     1
# 2      Bmw  2021   18000    2.0     1
# 3    Jetta  2015  150000    2.0     0
# 4     Audi  2017   70000    2.0     0

# %%
dataset['Novo'].value_counts()
# Out:
# 0    3
# 1    2
# Name: Novo, dtype: int64

# %%
classes_veiculos = {0:'Veiculos Antigos', 1:'Veiculos Novos'}

# %%
classes_veiculos
# Out:
# {0: 'Veiculos Antigos', 1: 'Veiculos Novos'}

# %%
dataset['Novo_Label'] = dataset['Novo'].map(classes_veiculos)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo    Classe Veiculo        Novo_Label
# 0      Gol  1999  100000    1.0     0  Veiculos Antigos  Veiculos Antigos
# 1  Ferrari  2020     900    5.0     1    Veiculos Novos    Veiculos Novos
# 2      Bmw  2021   18000    2.0     1    Veiculos Novos    Veiculos Novos
# 3    Jetta  2015  150000    2.0     0  Veiculos Antigos  Veiculos Antigos
# 4     Audi  2017   70000    2.0     0  Veiculos Antigos  Veiculos Antigos

# %%
dataset.drop(columns=['Classe Veiculo'], inplace=True)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo        Novo_Label
# 0      Gol  1999  100000    1.0     0  Veiculos Antigos
# 1  Ferrari  2020     900    5.0     1    Veiculos Novos
# 2      Bmw  2021   18000    2.0     1    Veiculos Novos
# 3    Jetta  2015  150000    2.0     0  Veiculos Antigos
# 4     Audi  2017   70000    2.0     0  Veiculos Antigos

# %%
def adiciona_um(x):
  return x + 1

# %%
dataset['Ano'] = dataset['Ano'].apply(adiciona_um)

# %%
dataset.head()
# Out:
#       Nome   Ano      Km  Motor  Novo        Novo_Label
# 0      Gol  2000  100000    1.0     0  Veiculos Antigos
# 1  Ferrari  2021     900    5.0     1    Veiculos Novos
# 2      Bmw  2022   18000    2.0     1    Veiculos Novos
# 3    Jetta  2016  150000    2.0     0  Veiculos Antigos
# 4     Audi  2018   70000    2.0     0  Veiculos Antigos

# %%
fn = lambda x: x + 1
fn(2)
# Out:
# 3

# %%
entrada = [2, 8, 14, 5, 7, 19]

# %%
list(map(lambda x: x + 1, entrada))
# Out:
# [3, 9, 15, 6, 8, 20]

# %%
dataset['Ano'] = dataset['Ano'].apply(lambda x: x + 1)

# %%
dataset
# Out:
#       Nome   Ano      Km  Motor  Novo        Novo_Label
# 0      Gol  2001  100000    1.0     0  Veiculos Antigos
# 1  Ferrari  2022     900    5.0     1    Veiculos Novos
# 2      Bmw  2023   18000    2.0     1    Veiculos Novos
# 3    Jetta  2017  150000    2.0     0  Veiculos Antigos
# 4     Audi  2019   70000    2.0     0  Veiculos Antigos

# %% [markdown]
# ### Tarefas de Hoje
#
# - Faça uma função que receba o ano do veiculo  e devolva 0 ou 1 para a coluna Novo
# - Tente reproduzir a função criada por lambda

# %%
aluguel.head()
# Out:
#                       Tipo           Bairro  ...    País  Valor_Completo
# 0                Quitinete       Copacabana  ...  Brasil          2200.0
# 1                     Casa  Jardim Botânico  ...  Brasil             NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...  Brasil          9220.0
# 3              Apartamento           Centro  ...  Brasil          1190.0
# 4              Apartamento     Higienópolis  ...  Brasil          1030.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Aluguel
#
# - Existem hoteis no dataset? Quais? Onde estão localizados?
# - Imoveis com suites estão localizdos em quais bairros?
# - Quais os 10 bairros com condominios mais barato do dataset?
# - Calcule o IPTU por metro, crie uma coluna com esse resultado
# - Calcule o valor por metro, crie uma coluna com esse resultado
# - Apresente os bairros com o metro mais caro de IPTU
# - Apresente os bairros com o metro mais caro de Valor
#
# - Apresente os mais baratos nessas condições tb
